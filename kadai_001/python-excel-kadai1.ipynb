# %%
import openpyxl

workbook = openpyxl.Workbook()
ws = workbook.active
ws['B2'] = '請求書'
ws['B4'] = '株式会社ABC'
ws['B5'] = '〒101-0022 東京都千代田区神田練塀町300'
ws['B6'] = 'TEL:03-1234-5678 FAX:03-1234-5678'
ws['B7'] = '担当者名:鈴木一郎 様'

# 空白行を2行追加（8行目・9行目）
ws.append([])  # row 1
ws.append([])  # row 2

# 表のヘッダー行を書き込む # ヘッダーを10行目、B列（列番号2）から書き込む
header = ['商品名', '数量', '単価', '金額']
start_row = 10
start_col = 2  # B列

for col_index, header in enumerate(header):
    ws.cell(row=start_row, column=start_col + col_index, value=header)



# 複数行のデータをリストdataに格納
data = [
    ['商品A', 2, 10000, 20000],
    ['商品B', 1, 15000, 15000],
    
]

# 繰り返し処理でrowに格納し1行ずつ追加
for row_offset, row_data in enumerate(data):
    for col_index, cell_value in enumerate(row_data):
        ws.cell(row=start_row + 1 + row_offset, column=start_col + col_index, value=cell_value)


# 合計行の位置
total_row = start_row + 1 + len(data)

# 合計の計算（金額だけ合計）
total_amount = sum(row[3] for row in data)

# 合計行の書き込み
ws.cell(row=total_row, column=start_col + 3, value=total_amount)

# 合計行の位置
total_row = start_row + 3+ len(data)

# 合計の計算（金額だけ合計）
total_amount = sum(row[3] for row in data)#小計
tax = total_amount*0.1
amount =total_amount+tax #こちらが合計

# 合計行の書き込み
ws.cell(row=total_row, column=start_col, value='小計')
ws.cell(row=total_row+ 1, column=start_col + 3, value=total_amount)

ws.cell(row=total_row, column=start_col, value='消費税')
ws.cell(row=total_row+ 2, column=start_col + 3, value=tax)

ws.cell(row=total_row, column=start_col, value='税込合計')
ws.cell(row=total_row+ 3, column=start_col + 3, value=amount)

workbook.save('請求書_20230520.xlsx')
